# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigrahalabhanu3/FFML-226Q1A4409/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-15 09:53:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  78.5MB/s    in 0.9s
#
# 2024-04-15 09:53:12 (78.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 4169 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 443  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25160  1506.02247v2  We study the existence and uniqueness of solut...    cs
# 19462   1107.0052v1  Many known planning tasks have inherent constr...    cs
# 10691   1212.0388v1  Most network-based protein (or gene) function ...  stat
# 22769  1706.02829v4  Time series analysis is used to understand and...  stat
# 23080  1803.06118v1  In the framework of the supervised learning of...  stat
# ...             ...                                                ...   ...
# 11434  1602.02164v1  We consider the problem of reconstructing a lo...  stat
# 6909   1707.05147v1  In this paper, we study the trade-offs of diff...  stat
# 25271  1507.01442v1  We introduce a novel dictionary optimization m...    cs
# 15725  1603.01360v3  State-of-the-art named entity recognition syst...    cs
# 29355  1709.01841v3  We propose a new method that uses deep learnin...    cs
#
#                                                    title  year  \
# 25160  Well-posedness of a nonlinear integro-differen...  2015
# 19462                      Ordered Landmarks in Planning  2011
# 10691  Hypergraph and protein function prediction wit...  2012
# 22769      Time Series Using Exponential Smoothing Cells  2017
# 23080  Gaussian Processes indexed on the symmetric gr...  2018
# ...                                                  ...   ...
# 11434  A Note on Alternating Minimization Algorithm f...  2016
# 6909   Comparative Study of Inference Methods for Bay...  2017
# 25271  Learning Better Encoding for Approximate Neare...  2015
# 15725  Neural Architectures for Named Entity Recognition  2016
# 29355  An inner-loop free solution to inverse problem...  2017
#
#                                                 keywords
# 25160  [existence, uniqueness, solutions, nonlinear, ...
# 19462  [constraints, concerning, constraints, approac...
# 10691  [prediction, assumption, relationship, informa...
# 22769  [understand, processes, including, biological,...
# 23080  [framework, supervised, euclidean, classical, ...
# ...                                                  ...
# 11434  [reconstructing, alternating, minimization, al...
# 6909   [different, inference, approaches, factorisati...
# 25271  [introduce, dictionary, optimization, dimensio...
# 15725  [recognition, knowledge, effectively, supervis...
# 29355  [techniques, accelerate, alternating, directio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25160    [existence, uniqueness, solutions, nonlinear, ...
# 19462    [constraints, concerning, constraints, approac...
# 10691    [prediction, assumption, relationship, informa...
# 22769    [understand, processes, including, biological,...
# 23080    [framework, supervised, euclidean, classical, ...
#                                ...
# 2562     [estimation, prevalence, population, analytics...
# 35912    [describes, affectively, intelligent, interact...
# 5043     [algorithms, successes, reinforcement, algorit...
# 9052     [expressly, uniqueness, specifically, sentimen...
# 32619    [comparison, information, comparison, specifie...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8825 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bef24c05-2dd0-48b9-8f84-f566184fefcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bef24c05-2dd0-48b9-8f84-f566184fefcf")) {                    Plotly.newPlot(                        "bef24c05-2dd0-48b9-8f84-f566184fefcf",                        [{"x":["nonlinear","differential","posedness","introducing","uniqueness","reformulate","rearranged","segmentation","properties","numerical","rearrangement","performance","formulation","dimensional","implemented","existence","decreasing","performed","reduction","filtering","processing","solutions","approximated","independent","demonstrates","constraints","considering","methodology","significant","decompose","exemplified","necessarily","implementation","approaches","concerning","definition","landmarks","completely","information","improvements","reasonable","introduced","represent","relationship","prediction","assumption","hypergraph","laplacian","constructed","functions","supervised","normalized","expression","experiment","symmetric","overcoming","functional","understand","including","capabilities","structured","illustrate","exponential","popularity","challenging","overlapping","parameters","forecasts","available","synthetic","smoothing","observations","processes","meaningful","tractable","experiments","situations","optimization","underlying","biological","nonconvex","dramatically","developments","efficient","interpretable","operators","commutative","forecasting","classical","euclidean","motivated","permutations","statistical","framework","covariance","outperform","literature","subgraphs","approximation","guarantees","algorithms","iterative","approximate","experimental","constraint","constrained","technical","detection","objective","demonstrate","statistics","variables","challenges","important","connected","bioinformatics","convergence","projected","analyzing","analogous","projection","connectivity","applications","thresholding","astronomy","incorporating","equivalent","distribution","estimation","competing","algorithm","improvement","resulting","introduce","nonparametric","maximization","distributions","simulations","interpretability","estimating","structures","assumptions","distributional","parametric","predictive","procedure","graphical","perspective","evaluation","sequential","entropies","occurring","adaptation","respectively","comparisons","mechanism","character","probabilities","perplexities","outperforms","immensely","attractive","significance","generation","conducted","constructive","technologies","procedural","effectiveness","artificial","intelligence","procedurally","generating","embeddings","different","configuration","recurrent","benchmark","hypotheses","distributed","contribution","correlates","convolutional","interactions","judgments","reference","translation","representations","generalizable","extensions","published","components","syntactic","topological","dimensionality","diversity","multiscale","providing","contribute","difficult"],"y":[49,34,3,58,6,4,3,211,207,73,2,913,76,159,98,39,10,116,112,70,284,130,22,133,52,138,72,74,241,20,5,17,136,410,17,38,14,38,728,117,31,145,113,70,255,61,2,15,60,226,198,30,44,82,25,5,39,68,239,40,94,83,58,20,266,22,255,6,268,138,16,70,114,53,33,603,53,313,107,43,12,19,18,414,34,50,2,14,102,34,54,4,160,533,20,106,114,4,120,48,616,82,99,380,84,65,36,366,176,561,71,150,121,363,69,11,108,20,77,14,51,28,457,11,1,67,53,226,182,30,803,156,152,337,9,20,130,44,15,69,138,54,25,48,59,110,53,64,251,67,6,15,67,88,31,87,52,68,2,263,2,21,26,119,63,5,38,6,206,136,91,2,96,67,756,27,146,223,28,94,74,1,388,83,11,55,103,227,7,54,42,118,49,26,55,30,8,103,31,157],"type":"bar"},{"x":["nonlinear","differential","posedness","introducing","uniqueness","ref ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Machine</span> <span style=''>Learner</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.42068965517241375);'>Automated</span> <span style='background-color:rgba(0, 255, 0, 0.7466666666666668);'>Reasoning</span> <span style=''>04</span> <span style=''>and</span> <span style=''>05</span> <br/><br/><span style=''>Machine</span> <span style=''>Learner</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.42068965517241375);'>Automated</span> <span style='background-color:rgba(0, 255, 0, 0.7466666666666668);'>Reasoning</span> <span style=''>(MaLARea)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7466666666666668);'>reasoning</span> <span style=''>system</span> <span style=''>for</span> <span style=''>proving</span> <span style=''>in</span> <span style=''>large</span> <span style=''>formal</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>libraries</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thousands</span> <span style=''>of</span> <span style=''>theorems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attacking</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjecture</span> <span style=''>and</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>related</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>proofs</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>specific</span> <span style=''>theorem</span> <span style=''>proving</span> <span style='background-color:rgba(0, 255, 0, 0.4029227557411274);'>knowledge</span> <span style=''>The</span> <span style=''>last</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style=''>has</span> <span style=''>by</span> <span style=''>a</span> <span style=''>large</span> <span style=''>margin</span> <span style=''>won</span> <span style=''>the</span> <span style=''>2013</span> <span style=''>CASC</span> <span style=''>LTB</span> <span style='background-color:rgba(0, 255, 0, 0.42105263157894723);'>competition</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>describes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3888888888888888);'>motivation</span> <span style=''>behind</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>used</span> <span style=''>in</span> <span style=''>MaLARea</span> <span style='background-color:rgba(0, 255, 0, 0.6875);'>discusses</span> <span style=''>the</span> <span style=''>general</span> <span style=''>approach</span> <span style=''>and</span> <span style=''>the</span> <span style=''>issues</span> <span style=''>arising</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.38292011019283745);'>evaluation</span> <span style=''>of</span> <span style=''>such</span> <span style=''>system</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>describes</span> <span style=''>the</span> <span style=''>MizarTuring100</span> <span style=''>and</span> <span style=''>CASC24</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>MaLARea</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Essentially</span> <span style=''>No</span> <span style=''>Barriers</span> <span style=''>in</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>Energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Landscape</span> <br/><br/><span style=''>Training</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>involves</span> <span style=''>finding</span> <span style=''>minima</span> <span style=''>of</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>loss</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>this</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>landscape</span> <span style=''>is</span> <span style=''>sparse</span> <span style=''>Relaxing</span> <span style=''>from</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolations</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>paths</span> <span style=''>between</span> <span style=''>minima</span> <span style=''>of</span> <span style=''>recent</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>on</span> <span style=''>CIFAR10</span> <span style=''>and</span> <span style=''>CIFAR100</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surprisingly</span> <span style=''>the</span> <span style=''>paths</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>flat</span> <span style=''>in</span> <span style=''>both</span> <span style=''>the</span> <span style=''>training</span> <span style=''>and</span> <span style=''>test</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>landscapes</span> <span style=''>This</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>enough</span> <span style=''>capacity</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>changes</span> <span style=''>or</span> <span style=''>that</span> <span style=''>these</span> <span style=''>changes</span> <span style=''>are</span> <span style=''>small</span> <span style=''>between</span> <span style=''>minima</span> <span style=''>Also</span> <span style=''>each</span> <span style=''>minimum</span> <span style=''>has</span> <span style=''>at</span> <span style=''>least</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>vanishing</span> <span style=''>Hessian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvalue</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>from</span> <span style=''>trivial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariance</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Latent</span> <span style=''>Tree</span> <span style=''>Models</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3687707641196014);'>Inference</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3687707641196014);'>inference</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>(BNs)</span> <span style=''>The</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>data</span> <span style=''>from</span> <span style=''>a</span> <span style=''>BN</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>tree</span> <span style=''>model</span> <span style=''>(LTM)</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>offline</span> <span style=''>and</span> <span style=''>when</span> <span style=''>online</span> <span style=''>make</span> <span style='background-color:rgba(255, 0, 0, 0.3687707641196014);'>inference</span> <span style=''>with</span> <span style=''>the</span> <span style=''>LTM</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style=''>BN</span> <span style=''>Because</span> <span style=''>LTMs</span> <span style=''>are</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3687707641196014);'>inference</span> <span style=''>takes</span> <span style=''>linear</span> <span style=''>time</span> <span style=''>In</span> <span style=''>the</span> <span style=''>meantime</span> <span style=''>they</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3216374269005847);'>represent</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>among</span> <span style=''>leaf</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>accuracy</span> <span style=''>is</span> <span style=''>often</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>evidence</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>achieve</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>accuracy</span> <span style=''>at</span> <span style=''>low</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>with</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>general</span> <span style=''>purpose</span> <span style=''>method</span> <span style=''>to</span> <span style=''>train</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>kernels</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>by</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>converge</span> <span style=''>and</span> <span style=''>mix</span> <span style=''>quickly</span> <span style=''>to</span> <span style=''>their</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>Our</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>and</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>expected</span> <span style=''>squared</span> <span style=''>jumped</span> <span style=''>distance</span> <span style=''>a</span> <span style=''>proxy</span> <span style=''>for</span> <span style=''>mixing</span> <span style=''>speed</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>gains</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>simple</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>for</span> <span style=''>instance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achieving</span> <span style=''>a</span> <span style=''>106x</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>in</span> <span style=''>one</span> <span style=''>case</span> <span style=''>and</span> <span style=''>mixing</span> <span style=''>when</span> <span style=''>standard</span> <span style=''>HMC</span> <span style=''>makes</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurable</span> <span style=''>progress</span> <span style=''>in</span> <span style=''>a</span> <span style=''>second</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitative</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitative</span> <span style=''>gains</span> <span style=''>on</span> <span style=''>a</span> <span style=''>real</span> <span style=''>world</span> <span style=''>task</span> <span style=''>latent</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>modeling</span> <span style=''>We</span> <span style=''>release</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>TensorFlow</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12701252236135957)
# 	knowledge (0.12021466905187836)
# 	experimental (0.13595706618962433)
# 	architecture (0.09373881932021468)
# 	segmentation (0.07549194991055456)
# 	information (0.26046511627906976)
# 	detection (0.13094812164579606)
# 	different (0.2704830053667263)
# 	convolutional (0.13881932021466906)
# 	recognition (0.13846153846153847)
#
# Some Statistics words are:
# 	variables (0.14064837905236907)
# 	theoretical (0.14713216957605985)
# 	stochastic (0.14214463840399003)
# 	estimation (0.16408977556109725)
# 	statistical (0.15910224438902743)
# 	distribution (0.18354114713216957)
# 	algorithm (0.3905236907730673)
# 	inference (0.20548628428927682)
# 	regression (0.18503740648379052)
# 	dimensional (0.19950124688279303)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="619dbe85-9458-41ef-a783-1c5757e8e5ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("619dbe85-9458-41ef-a783-1c5757e8e5ce")) {                    Plotly.newPlot(                        "619dbe85-9458-41ef-a783-1c5757e8e5ce",                        [{"x":["nonlinear","differential","posedness","introducing","uniqueness","reformulate","rearranged","segmentation","properties","numerical","rearrangement","performance","formulation","dimensional","implemented","existence","decreasing","performed","reduction","filtering","processing","solutions","approximated","independent","demonstrates","constraints","considering","methodology","significant","decompose","exemplified","necessarily","implementation","approaches","concerning","definition","landmarks","completely","information","improvements","reasonable","introduced","represent","relationship","prediction","assumption","hypergraph","laplacian","constructed","functions","supervised","normalized","expression","experiment","symmetric","overcoming","functional","understand","including","capabilities","structured","illustrate","exponential","popularity","challenging","overlapping","parameters","forecasts","available","synthetic","smoothing","observations","processes","meaningful","tractable","experiments","situations","optimization","underlying","biological","nonconvex","dramatically","developments","efficient","interpretable","operators","commutative","forecasting","classical","euclidean","motivated","permutations","statistical","framework","covariance","outperform","literature","subgraphs","approximation","guarantees","algorithms","iterative","approximate","experimental","constraint","constrained","technical","detection","objective","demonstrate","statistics","variables","challenges","important","connected","bioinformatics","convergence","projected","analyzing","analogous","projection","connectivity","applications","thresholding","astronomy","incorporating","equivalent","distribution","estimation","competing","algorithm","improvement","resulting","introduce","nonparametric","maximization","distributions","simulations","interpretability","estimating","structures","assumptions","distributional","parametric","predictive","procedure","graphical","perspective","evaluation","sequential","entropies","occurring","adaptation","respectively","comparisons","mechanism","character","probabilities","perplexities","outperforms","immensely","attractive","significance","generation","conducted","constructive","technologies","procedural","effectiveness","artificial","intelligence","procedurally","generating","embeddings","different","configuration","recurrent","benchmark","hypotheses","distributed","contribution","correlates","convolutional","interactions","judgments","reference","translation","representations","generalizable","extensions","published","components","syntactic","topological","dimensionality","diversity","multiscale","providing","contribute","difficult","classification","favorably","theoretical","specifically","ensembles","combining","leveraging","regression","neighborhoods","stability","increased","robustness","possibility","multidimensional","coverings","highlight","reductions","operating","integrating","estimated","beneficial","recognition","increasing","depending","availability","rescoring","summarize","transcription","automatic","computationally","estimators","likelihood","kronecker","triangles","parsimonious","prominent","stochastic","typically","especially","polynomial","combinatorial","contributions","decomposed","counterparts","accompanied","collection","processed","complexity","decomposition","corrupted","effective","communication","according","remaining","considered","con ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	recombines
# 	originating
# 	unbiasedness
# 	expecting
# 	contributors
# 	biomarker
# 	encountering
# 	couplings
# 	reversing
# 	ultrametric
# 	tabulation
# 	strongest
# 	reassignment
# 	deflation
# 	formalizes
# 	movielens
# 	repeatmulti
# 	nonadaptive
# 	oscillations
# 	unprocessed
# Some words which never appear in Statistics papers:
# 	rearranged
# 	rearrangement
# 	perplexities
# 	immensely
# 	procedurally
# 	extraneous
# 	connectivities
# 	monocular
# 	illumination
# 	constancy
# 	reflection
# 	evolvability
# 	unnatural
# 	conjunctions
# 	reflective
# 	manipulators
# 	warehouse
# 	personalisation
# 	distractors
# 	functionalities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.073613032119256e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
